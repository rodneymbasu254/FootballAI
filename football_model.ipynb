# %%
import pandas as pd

df = pd.read_csv("newData.csv")
df.describe()
# Out:
#          Unnamed: 0           age     height_cm    weight_kgs  overall_rating  \
# count  17954.000000  17954.000000  17954.000000  17954.000000    17954.000000
# mean    8976.500000     25.565445    174.946921     75.301047       66.240169
# std     5183.017702      4.705708     14.029449      7.083684        6.963730
# min        0.000000     17.000000    152.400000     49.900000       47.000000
# 25%     4488.250000     22.000000    154.940000     69.900000       62.000000
# 50%     8976.500000     25.000000    175.260000     74.800000       66.000000
# 75%    13464.750000     29.000000    185.420000     79.800000       71.000000
# max    17953.000000     46.000000    205.740000    110.200000       94.000000
#
#           potential    value_euro      wage_euro  \
# count  17954.000000  1.769900e+04   17708.000000
# mean      71.430935  2.479280e+06    9902.134628
# std        6.131339  5.687014e+06   21995.593750
# min       48.000000  1.000000e+04    1000.000000
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'full_name', 'birth_date', 'age', 'height_cm',
#        'weight_kgs', 'positions', 'nationality', 'overall_rating', 'potential',
#        'value_euro', 'wage_euro', 'preferred_foot',
#        'international_reputation(1-5)', 'weak_foot(1-5)', 'skill_moves(1-5)',
#        'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'dribbling', 'curve', 'freekick_accuracy', 'long_passing',
#        'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions',
#        'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
#        'composure', 'marking', 'standing_tackle', 'sliding_tackle'],
#       dtype='object')

# %%
df.dropna(axis = 0)
# Out:
#        Unnamed: 0            name                         full_name  \
# 0               0        L. Messi    Lionel Andrés Messi Cuccittini
# 1               1      C. Eriksen      Christian  Dannemann Eriksen
# 2               2        P. Pogba                        Paul Pogba
# 3               3      L. Insigne                   Lorenzo Insigne
# 4               4    K. Koulibaly                 Kalidou Koulibaly
# ...           ...             ...                               ...
# 17949       17949     R. McKenzie                    Rory  McKenzie
# 17950       17950       M. Sipľak                     Michal Sipľak
# 17951       17951      J. Bekkema                       Jan Bekkema
# 17952       17952      A. Al Yami               Abdulrahman Al Yami
# 17953       17953  Júnior Brumado  José Francisco dos Santos Júnior
#
#       birth_date  age  height_cm  weight_kgs  positions   nationality  \
# 0      6/24/1987   31     170.18        72.1   CF,RW,ST     Argentina
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'full_name', 'birth_date', 'age', 'height_cm',
#        'weight_kgs', 'positions', 'nationality', 'overall_rating', 'potential',
#        'value_euro', 'wage_euro', 'preferred_foot',
#        'international_reputation(1-5)', 'weak_foot(1-5)', 'skill_moves(1-5)',
#        'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'dribbling', 'curve', 'freekick_accuracy', 'long_passing',
#        'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions',
#        'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
#        'composure', 'marking', 'standing_tackle', 'sliding_tackle'],
#       dtype='object')

# %%
y = df.overall_rating
features = ['strength','vision', 'jumping']
X = df[features]
X.describe()
# Out:
#            strength        vision       jumping
# count  17954.000000  17954.000000  17954.000000
# mean      65.158850     53.406260     64.955219
# std       12.535955     14.156038     11.705711
# min       20.000000     10.000000     15.000000
# 25%       58.000000     44.000000     58.000000
# 50%       66.000000     55.000000     66.000000
# 75%       74.000000     64.000000     73.000000
# max       97.000000     94.000000     95.000000

# %%
X.head()
# Out:
#    strength  vision  jumping
# 0        66      94       68
# 1        58      91       50
# 2        87      88       83
# 3        44      87       53
# 4        94      49       81

# %%
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
football_model = linear_model.LinearRegression()
football_model.fit(X, y)
prediction = football_model.predict(X)

print(prediction)

mean_absolute_error(y, prediction)
# Out:
# [76.81291862 73.08615318 80.47664152 ... 56.92175159 62.28887652
#  65.07554102]
# 4.183087638254157

# %%
from sklearn.model_selection import train_test_split
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 1)
football_model = DecisionTreeRegressor(random_state = 1)
football_model.fit(train_X, train_y)
val_predictions = football_model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 from sklearn import DecisionTreeRegressor
#       3 train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 1)
#       4 football_model = DecisionTreeRegressor(random_state = 1)
#
# ImportError: cannot import name 'DecisionTreeRegressor' from 'sklearn' (C:\Users\Home\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\__init__.py)

# %%
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes = max_leaf_nodes, random_state = 1)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

# %%
candidate_leaf_nodes = [5, 50, 500, 5000]
for max_leaf_nodes in candidate_leaf_nodes:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d \t\t Mean absolute error: %d" %(max_leaf_nodes, my_mae))

scores = {leaf_size: get_mae(leaf_size, train_X, val_X, train_y, val_y)
         for leaf_size in candidate_leaf_nodes}
print("\n", scores)

best_tree_size = min(scores, key=scores.get)
print("\n", best_tree_size, scores[best_tree_size])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 candidate_leaf_nodes = [5, 50, 500, 5000]
#       2 for max_leaf_nodes in candidate_leaf_nodes:
# ----> 3     my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
#       4     print("Max leaf nodes: %d \t\t Mean absolute error: %d" %(max_leaf_nodes, my_mae))
#       6 scores = {leaf_size: get_mae(leaf_size, train_X, val_X, train_y, val_y)
#       7          for leaf_size in candidate_leaf_nodes}
#
# NameError: name 'get_mae' is not defined

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

fr_model = RandomForestRegressor(random_state = 1)
fr_model.fit(train_X, train_y)
fr_preds = fr_model.predict(val_X)
print(mean_absolute_error(val_y, fr_preds))
print(mean_squared_error(val_y, fr_preds))
# Out:
# 4.06924734852163
# 26.970690729396253

# %%
import graphviz

# %%
import matplotlib.pyplot as plt
from sklearn.inspection import PartialDependenceDisplay
disp1 = PartialDependenceDisplay.from_estimator(fr_model, val_X, ['strength'])
plt.show()

# %%
print(max(prediction))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(max(prediction))
#
# NameError: name 'prediction' is not defined

# %%
print(min(prediction))
